# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
#question 1
#data preprocessing

#Loading dataset
titanic = sns.load_dataset('titanic')

#dropping unneeded values and recoding sex and embarked
titanic = titanic.drop(['class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone'], axis=1)
titanic['age'].fillna(titanic.groupby('pclass')['age'].transform("median"), inplace=True)
titanic.dropna(inplace=True)

new_sex = pd.get_dummies(titanic['sex'], drop_first=True)
new_embarked = pd.get_dummies(titanic['embarked'], drop_first=True)

titanic = pd.concat([titanic, new_sex, new_embarked], axis=1)
titanic.drop(['sex', 'embarked'],axis=1, inplace=True)

#show table of the data
titanic.head()
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.382452    2.311586   29.019314    0.524184    0.382452   32.096681
# std      0.486260    0.834700   13.209814    1.103705    0.806761   49.697504
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   26.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   36.500000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#              male           Q           S
# count  889.000000  889.000000  889.000000
# mean     0.649044    0.086614    0.724409
# std      0.477538    0.281427    0.447063
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# ...

# %%
#question 2
#create train/test split
# library to split dataset into train and test
from sklearn.model_selection import train_test_split

# X is all possible features/independent variables, Y is what we are modeling
X = titanic.drop('survived', axis=1)
Y = titanic['survived']

# split the data with 30% of rows going to the training set and a state seed of 1000 for consistency
trainX, testX, trainY, testY = train_test_split(X,Y,test_size=0.3, random_state = 1000)

# print the shape of the split dataframes
trainX.shape, trainY.shape, testX.shape, testY.shape

# started with 889 observations - 622 are for training and 267 for testing
# Out:
# ((622, 8), (622,), (267, 8), (267,))

# %%
#question 3
from sklearn import tree

#make a tree with default options
treemax = tree.DecisionTreeClassifier()

#fit with data
treemax = treemax.fit(trainX, trainY)

print('the accuracy rate on training data is', treemax.score(trainX, trainY))

print('the accuracy rate on testing data is', treemax.score(testX, testY))

# create graph of decision tree
import graphviz
treemax_graph = tree.export_graphviz(treemax, out_file=None, 
            feature_names=['pclass', 'age', 'sibsp', 'parch', 'fare', 'male', 'Q', 'S'],
            class_names = ['did not survive', 'survived']  ,                        
            filled=True, rounded=True,  
            special_characters=True)  
graph = graphviz.Source(treemax_graph)  
graph
# Out:
# the accuracy rate on training data is 0.9887459807073955
# the accuracy rate on testing data is 0.7640449438202247

# %%
#question 4 and 5
# remake the tree with a max depth of 2
treedepth = tree.DecisionTreeClassifier(max_depth = 2)

# fit with data
treedepth = treedepth.fit(trainX, trainY)

print('the accuracy rate on training data is', treedepth.score(trainX, trainY))

print('the accuracy rate on testing data is', treedepth.score(testX, testY))

# create graph of second decision tree
import graphviz
treedepth_graph = tree.export_graphviz(treedepth, out_file=None, 
            feature_names=['pclass', 'age', 'sibsp', 'parch', 'fare', 'male', 'Q', 'S'],
            class_names = ['did not survive', 'survived']  ,                        
            filled=True, rounded=True,  
            special_characters=True)
graph = graphviz.Source(treedepth_graph)
graph
# Out:
# the accuracy rate on training data is 0.8054662379421221
# the accuracy rate on testing data is 0.7715355805243446

# %%
#question 6

#test 1
tree1 = tree.DecisionTreeClassifier(max_depth = 2, min_samples_leaf = 1)
tree1.fit(trainX, trainY)

print("Test 1")
print("Accuracy on the train set {:.3f}%".format(tree1.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree1.score(testX, testY) * 100))

#test 2
tree2 = tree.DecisionTreeClassifier(max_depth = 3, min_samples_leaf = 1)
tree2.fit(trainX, trainY)

print("\nTest 2")
print("Accuracy on the train set {:.3f}%".format(tree2.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree2.score(testX, testY) * 100))

#test 3
tree3 = tree.DecisionTreeClassifier(max_depth = 3, min_samples_leaf = 10)
tree3.fit(trainX, trainY)

print("\nTest 3")
print("Accuracy on the train set {:.3f}%".format(tree3.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree3.score(testX, testY) * 100))

#test 4
tree4 = tree.DecisionTreeClassifier(max_depth = 3, min_samples_leaf = 25)
tree4.fit(trainX, trainY)

print("\nTest 4")
print("Accuracy on the train set {:.3f}%".format(tree4.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree4.score(testX, testY) * 100))

#test 5
tree5 = tree.DecisionTreeClassifier(max_depth = 4, min_samples_leaf = 1)
tree5.fit(trainX, trainY)

print("\nTest 5")
print("Accuracy on the train set {:.3f}%".format(tree5.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree5.score(testX, testY) * 100))

#test 6
tree6 = tree.DecisionTreeClassifier(max_depth = 4, min_samples_leaf = 10)
tree6.fit(trainX, trainY)

print("\nTest 6")
print("Accuracy on the train set {:.3f}%".format(tree6.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree6.score(testX, testY) * 100))

#test 7
tree7 = tree.DecisionTreeClassifier(max_depth = 4, min_samples_leaf = 25)
tree7.fit(trainX, trainY)

print("\nTest 7")
print("Accuracy on the train set {:.3f}%".format(tree7.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree7.score(testX, testY) * 100))

#test 8
tree8 = tree.DecisionTreeClassifier(max_depth = 5, min_samples_leaf = 1)
tree8.fit(trainX, trainY)

print("\nTest 8")
print("Accuracy on the train set {:.3f}%".format(tree8.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree8.score(testX, testY) * 100))

#test 9
tree9 = tree.DecisionTreeClassifier(max_depth = 5, min_samples_leaf = 10)
tree9.fit(trainX, trainY)

print("\nTest 9")
print("Accuracy on the train set {:.3f}%".format(tree9.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree9.score(testX, testY) * 100))

#test 10
tree10 = tree.DecisionTreeClassifier(max_depth = 5, min_samples_leaf = 25)
tree10.fit(trainX, trainY)

print("\nTest 10")
print("Accuracy on the train set {:.3f}%".format(tree10.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree10.score(testX, testY) * 100))

#test 11
tree11 = tree.DecisionTreeClassifier(max_depth = 6, min_samples_leaf = 1)
tree11.fit(trainX, trainY)

print("\nTest 11")
print("Accuracy on the train set {:.3f}%".format(tree11.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree11.score(testX, testY) * 100))

#test 12
tree12 = tree.DecisionTreeClassifier(max_depth = 6, min_samples_leaf = 10)
tree12.fit(trainX, trainY)

print("\nTest 12")
print("Accuracy on the train set {:.3f}%".format(tree12.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree12.score(testX, testY) * 100))

#test 13
tree13 = tree.DecisionTreeClassifier(max_depth = 6, min_samples_leaf = 25)
tree13.fit(trainX, trainY)

print("\nTest 13")
print("Accuracy on the train set {:.3f}%".format(tree13.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree13.score(testX, testY) * 100))

#test 14
tree14 = tree.DecisionTreeClassifier(max_depth = 7, min_samples_leaf = 1)
tree14.fit(trainX, trainY)

print("\nTest 14")
print("Accuracy on the train set {:.3f}%".format(tree14.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree14.score(testX, testY) * 100))

#test 15
tree15 = tree.DecisionTreeClassifier(max_depth = 7, min_samples_leaf = 10)
tree15.fit(trainX, trainY)

print("\nTest 15")
print("Accuracy on the train set {:.3f}%".format(tree15.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree15.score(testX, testY) * 100))

#test 16
tree16 = tree.DecisionTreeClassifier(max_depth = 7, min_samples_leaf = 25)
tree16.fit(trainX, trainY)

print("\nTest 16")
print("Accuracy on the train set {:.3f}%".format(tree16.score(trainX, trainY) * 100))
print("Accuracy on the test set {:.3f}%".format(tree16.score(testX, testY) * 100))
# Out:
# Test 1
# Accuracy on the train set 80.547%
# Accuracy on the test set 77.154%
#
# Test 2
# Accuracy on the train set 83.119%
# Accuracy on the test set 79.775%
#
# Test 3
# Accuracy on the train set 82.797%
# Accuracy on the test set 79.401%
#
# Test 4
# Accuracy on the train set 81.994%
# Accuracy on the test set 79.775%
#
# Test 5
# Accuracy on the train set 84.887%
# Accuracy on the test set 80.150%
#
# Test 6
# Accuracy on the train set 84.244%
# Accuracy on the test set 80.150%
#
# Test 7
# Accuracy on the train set 81.994%
# Accuracy on the test set 79.775%
#
# Test 8
# Accuracy on the train set 85.370%
# Accuracy on the test set 80.150%
#
# Test 9
# Accuracy on the train set 84.405%
# Accuracy on the test set 79.026%
#
# Test 10
# Accuracy on the train set 82.315%
# Accuracy on the test set 78.652%
#
# Test 11
# Accuracy on the train set 88.103%
# Accuracy on the test set 80.899%
#
# Test 12
# Accuracy on the train set 85.691%
# Accuracy on the test set 79.026%
#
# Test 13
# ...
